# %% [markdown]
# ## JSON output

# %%
import pandas as pd
import getpass

# %%
api_key=getpass.getpass()
# Out:
#  ······

# %%
df=pd.read_json(f'http://clustercien.udea.edu.co/viceinv/{api_key}/InstituLAC.json')

# %%
dff=df[df['Group'].astype(str).str.lower().str.contains('interacciones')][['FRH_P-TES_MAST_P']]#, 'FRH_P-TES_MAST_P',
       #'FRH_P-TES_PREG_P']]['FRH_P-TES_MAST_P'].to_list()
pd.DataFrame( dff.iloc[-1].to_list()[0] )[['Título','Institución','Fecha inicio','Fecha fin']]
# Out:
#                                               Título  \
# 0  Desarrollo de Trigger de Alto Nivel para un Mo...
# 1                       Producción de Materia Oscura
#
#                 Institución Fecha inicio Fecha fin
# 0  UNIVERSIDAD DE ANTIOQUIA       2017-8    2019-5
# 1  UNIVERSIDAD DE ANTIOQUIA       2017-6    2020-2

# %%
for t in ['FRH_P-TES_DOC_P', 'FRH_P-TES_MAST_P','FRH_P-TES_PREG_P']:
    nt=len(df[t].dropna().sum())
    n=len( [d.get('Autor') for d  in df[t].dropna().sum() if d.get('Autor')] )
    print( f'{t} → {nt} : {n} : {n/nt*100}' )
# Out:
# FRH_P-TES_DOC_P → 346 : 336 : 97.10982658959537
# FRH_P-TES_MAST_P → 1546 : 1373 : 88.80983182406209
# FRH_P-TES_PREG_P → 2106 : 1775 : 84.28300094966762

# %%
pd.DataFrame( df['FRH_P-TES_DOC_P'].dropna().sum() ).sort_values('Autor').reset_index(drop=True)[:50][
    ['Título','Institución','Fecha inicio','Fecha fin']]
# Out:
#                                                Título  \
# 0   Dynamics of continental water storage in regio...
# 1   CARACTERIZACIÓN FISICOQUÍMICA Y CLASIFICACIÓN ...
# 2                    Actos de fe: permiso para creer.
# 3   Actividad anticancerígena inducida mediante hí...
# 4   Dinámica del Delta del Atrato y su Influencia ...
# 5   ¿Razones que motivan a los estudiantes para ir...
# 6   El hilo de Ariadna: concepto y prácticas de ed...
# 7   Estudio de la biota edáfica en el Cultivo del ...
# 8   EVALUACIÓN DE UNA BASE COMÚN EN LA ETIOLOGÍA G...
# 9   El museo de arte como escenario para la constr...
# 10  Estudio epidemiológico y caracterización molec...
# 11  Functional genomics of cocoa antioxidants in t...
# 12  Light regulation of cocoa secondary metabolite...
# 13  Light regulation of cacao secondary metabolite...
# 14  Análisis y descripción lingüística de las locu...
# 15  Co-construcción de conocimiento en un aula de ...
# 16  EVALUACION NEUROPATOLÓGICA Y COGNITIVA ASOCIAD...
# 17  Desarrollo de recubrimientos biocompatibles y ...
# 18  DREQUS: an approach for the Discovery of REQui...
# 19  Diseño de un programa de mejoramiento genético...
# 20  El juicio de los espectadores de Hannah Arendt...
# 21  El hilo de Ariadna: concepto y prácticas de ed...
# 22  Señalización y Citoesqueleto en la Biología de...
# 23  CÁLCULO DE LA RESPUESTA ÓPTICA NO LINEAL EN UN...
# 24                               Formación en máquina
# 25  Variantes genéticas y neuroanatómicas asociada...
# 26  Modulación del fenómeno de citoadherencia de P...
# 27  AVALIAÇÃO DA LIOFILIZAÇÃO PARA PRODUÇÃO DE CRI...
# 28  Marcadores clínicos, genéticos y neuroanatómic...
# 29  Evaluation of the environmental and energetic ...
# 30  Recuperación de oro y paladio a partir de resi...
# 31  Estudio de la dinámica de sistemas EGSB en la ...
# 32  Effect of hydrocarbons in the SCR of NOx with ...
# 33  String and Band Complexes over String Almost G...
# 34  Imunoproteômica de Paracoccidioides spp com ap...
# 35  Propiedades Magnéticas y Catalíticas de Sistem...
# 36                      METAGENOMICS BINNING PLATFORM
# 37  EEG Connectivity Measures for Discriminating T...
# 38  Efectos de los AGCS dela OMC sobre la salud de...
# 39  Determination of lipid biomarkers involved in ...
# 40  Estudio de las propiedades quimiopreventivas d...
# 41  Estudio de las Propiedades Quimiopreventivas d...
# 42  Caracterización clínica, endocrina y metabólic...
# 43  Efficient Storage of Genomic Sequences in High...
# 44  Construcción de Modelos de Velocidad y Análisi...
# 45  Efficient Storage of Genomic Sequences in High...
# 46  Evaluación de la utilidad clínica de marcadore...
# 47  Mezclas de alcoholes con combustibles diésel: ...
# 48  "Tierrita de mi tierra. Reconstruir lugares ap...
# 49  Tierrita de mi tierra. Reconstruir lugares apr...
#
#                                           Institución Fecha inicio Fecha fin
# 0                            UNIVERSIDAD DE ANTIOQUIA       2016-2   2020-12
# 1                            UNIVERSIDAD DE ANTIOQUIA       2014-9    2018-4
# 2                                   UNIVERSIDAD EAFIT       2017-1    2021-4
# 3                            UNIVERSIDAD DE ANTIOQUIA       2015-2    2020-3
# 4                            UNIVERSIDAD DE ANTIOQUIA       2016-1    2021-7
# 5                  Universidad Nacional de Entre Ríos       2017-1   2020-10
# 6                            UNIVERSIDAD DE ANTIOQUIA       2014-2    2018-2
# 7                            UNIVERSIDAD DE ANTIOQUIA       2014-1   2017-11
# 8                            UNIVERSIDAD DE ANTIOQUIA       2009-8    2018-8
# 9                            UNIVERSIDAD DE ANTIOQUIA       2017-2   2020-12
# 10                           University of Greifswald       2015-4    2018-9
# 11                           UNIVERSIDAD DE ANTIOQUIA       2015-1    2020-1
# 12                           UNIVERSIDAD DE ANTIOQUIA       2015-1    2020-2
# 13                           UNIVERSIDAD DE ANTIOQUIA       2014-8   2019-12
# 14                           UNIVERSIDAD DE ANTIOQUIA       2019-1   2020-12
# 15                           UNIVERSIDAD DE ANTIOQUIA       2012-1   2016-11
# 16       UNIVERSIDAD NACIONAL DE COLOMBIA SEDE BOGOTA       2012-1   2015-12
# 17                           UNIVERSIDAD DE ANTIOQUIA       2013-7   2017-12
# 18                           UNIVERSIDAD DE ANTIOQUIA       2018-7   2020-10
# 19  Facultad de Ciencias Agrarias Universidad de A...       2016-1   2019-11
# 20                           UNIVERSIDAD DE ANTIOQUIA       2007-2    2011-9
# 21                           UNIVERSIDAD DE ANTIOQUIA       2014-2    2018-2
# 22                           UNIVERSIDAD DE ANTIOQUIA       2013-1    2020-2
# 23                               UNIVERSIDAD DE SUCRE       2014-1    2018-6
# 24                    UNIVERSIDAD PEDAGÓGICA NACIONAL       2011-2    2017-6
# 25                           UNIVERSIDAD DE ANTIOQUIA       2016-2    2020-7
# 26                           UNIVERSIDAD DE ANTIOQUIA       2012-1    2012-6
# 27  CAPES - Coordenação de aperfeiçoamento de pess...       2015-3    2019-4
# 28                           UNIVERSIDAD DE ANTIOQUIA       2016-6    2020-5
# 29                           UNIVERSIDAD DE ANTIOQUIA       2015-2    2019-5
# 30                           UNIVERSIDAD DE ANTIOQUIA       2013-8   2018-12
# 31                           UNIVERSIDAD DE ANTIOQUIA       2014-2   2018-12
# 32    Ministerio de Ciencia, Tecnología e Innovación.       2015-1    2020-9
# 33                           UNIVERSIDAD DE ANTIOQUIA       2018-6    2020-7
# 34                      Universidade Federal de Goiás      2014-10   2018-10
# 35                           UNIVERSIDAD DE ANTIOQUIA       2016-1    2020-7
# 36                           UNIVERSIDAD DE ANTIOQUIA       2015-1   2019-10
# 37                           UNIVERSIDAD DE ANTIOQUIA       2015-2    2019-3
# 38                            Universidad De Alicante       2010-3   2015-11
# 39                           UNIVERSIDAD DE ANTIOQUIA       2015-1    2020-8
# 40                           UNIVERSIDAD DE ANTIOQUIA       2015-1   2019-12
# 41                           UNIVERSIDAD DE ANTIOQUIA       2015-1    2020-3
# 42                           UNIVERSIDAD DE ANTIOQUIA       2018-1    2018-1
# 43                           UNIVERSIDAD DE ANTIOQUIA       2015-1    2020-5
# 44                           UNIVERSIDAD DE ANTIOQUIA       2014-2    2019-6
# 45                           UNIVERSIDAD DE ANTIOQUIA       2014-7    2019-6
# 46                           UNIVERSIDAD DE ANTIOQUIA       2014-1   2019-10
# 47                           UNIVERSIDAD DE ANTIOQUIA       2015-6    2020-9
# 48  Centro De Investigaciones Facultad Nacional De...       2017-2    2020-1
# 49                           UNIVERSIDAD DE ANTIOQUIA       2015-7    2020-9
